# %%
import requests
from bs4 import BeautifulSoup
base_url = "https://buy.housefun.com.tw/region/%E5%8F%B0%E5%8C%97%E5%B8%82-%E6%96%87%E5%B1%B1%E5%8D%80_c/%E7%84%A1%E9%9B%BB%E6%A2%AF%E5%85%AC%E5%AF%93_type/?pg="
page_number = 1

result_list = []

def is_last_page(soup):
    # Find the anchor tag with the class "has-arrow"
    next_button = soup.find('li', class_='has-arrow')

    # If the anchor tag is not found, it means this is the last page
    return next_button is None

while True:
    # Make a GET request to the current page URL
    url = base_url + str(page_number)
    response = requests.get(url)
    html = response.content

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')

    # Extract and process the desired information
    districts = "Wenshan"
    types = "apartment"
    ping_numbers = [em.find(class_="number").text.strip() for em in soup.find_all(class_="ping-number")]
    discount_prices = [em.find(class_="number").text.strip() for em in soup.find_all(class_="discount-price")]
    
    # Calculate the unit prices by dividing discount price by square
    # unit_prices = [f'{float(discount_price.replace(",", "")) / float(ping_number):.2f}' for discount_price, ping_number in zip(discount_prices, ping_numbers)]
    
    for ping_number, discount_price  in zip(ping_numbers, discount_prices):
        # Create a dictionary to store the extracted information for each item
        if ping_number == '--':
            continue
        else:
            unit_price = float(discount_price.replace(",", "")) / float(ping_number)
            data = {
                "district": districts,
                "type": types,
                "square": ping_number,
                "square_price":  f"{unit_price:.2f}",
                "total_price": discount_price
            }
        
        # Append the dictionary to the result list
        result_list.append(data)

    # Check if the last page has been reached
    if is_last_page(soup):
        break

    # Increment the page number for the next iteration
    page_number += 1

# Print the extracted information for each item
for item in result_list:
    print(item)

# You can access the result_list outside the loop for further processing
print("Total items:", len(result_list))
# Out:
# {'district': 'Wenshan', 'type': 'apartment', 'square': '36.27', 'square_price': '49.57', 'total_price': '1,798'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '35.92', 'square_price': '72.05', 'total_price': '2,588'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '47.99', 'square_price': '81.02', 'total_price': '3,888'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.29', 'square_price': '74.70', 'total_price': '2,188'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.35', 'square_price': '54.10', 'total_price': '1,750'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '65', 'square_price': '83.08', 'total_price': '5,400'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.18', 'square_price': '67.25', 'total_price': '1,895'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32', 'square_price': '52.12', 'total_price': '1,668'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '33.89', 'square_price': '55.47', 'total_price': '1,880'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.69', 'square_price': '55.07', 'total_price': '1,580'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '43.65', 'square_price': '45.77', 'total_price': '1,998'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '30.93', 'square_price': '70.74', 'total_price': '2,188'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '37.99', 'square_price': '52.12', 'total_price': '1,980'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '43.6', 'square_price': '66.51', 'total_price': '2,900'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '13.87', 'square_price': '71.23', 'total_price': '988'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '24.95', 'square_price': '111.82', 'total_price': '2,790'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '34.56', 'square_price': '49.19', 'total_price': '1,700'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.13', 'square_price': '51.55', 'total_price': '1,450'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '33.39', 'square_price': '56.84', 'total_price': '1,898'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '48.35', 'square_price': '45.50', 'total_price': '2,200'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.29', 'square_price': '74.70', 'total_price': '2,188'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '74.19', 'square_price': '93.68', 'total_price': '6,950'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '51.96', 'square_price': '140.11', 'total_price': '7,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '30', 'square_price': '96.87', 'total_price': '2,906'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '35.71', 'square_price': '128.26', 'total_price': '4,580'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '43.66', 'square_price': '60.70', 'total_price': '2,650'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.76', 'square_price': '58.41', 'total_price': '1,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '35.95', 'square_price': '49.51', 'total_price': '1,780'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '19.17', 'square_price': '70.42', 'total_price': '1,350'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '31.26', 'square_price': '65.58', 'total_price': '2,050'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '21.16', 'square_price': '63.80', 'total_price': '1,350'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.2', 'square_price': '50.74', 'total_price': '1,380'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '21.18', 'square_price': '122.19', 'total_price': '2,588'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '34.46', 'square_price': '49.91', 'total_price': '1,720'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '44.4', 'square_price': '96.40', 'total_price': '4,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.82', 'square_price': '119.05', 'total_price': '3,550'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '24.18', 'square_price': '81.89', 'total_price': '1,980'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '54.21', 'square_price': '62.35', 'total_price': '3,380'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.47', 'square_price': '72.81', 'total_price': '2,000'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '47.52', 'square_price': '51.56', 'total_price': '2,450'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.5', 'square_price': '52.73', 'total_price': '1,450'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '30.59', 'square_price': '48.97', 'total_price': '1,498'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.53', 'square_price': '130.04', 'total_price': '3,580'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '34.71', 'square_price': '68.86', 'total_price': '2,390'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '33.67', 'square_price': '79.83', 'total_price': '2,688'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '50.44', 'square_price': '45.36', 'total_price': '2,288'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '33.49', 'square_price': '62.11', 'total_price': '2,080'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '37.19', 'square_price': '47.86', 'total_price': '1,780'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '38.34', 'square_price': '48.25', 'total_price': '1,850'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '43.15', 'square_price': '63.73', 'total_price': '2,750'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '39.55', 'square_price': '60.18', 'total_price': '2,380'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.14', 'square_price': '53.48', 'total_price': '1,398'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.32', 'square_price': '61.32', 'total_price': '1,798'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '23.76', 'square_price': '60.44', 'total_price': '1,436'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '38.74', 'square_price': '51.37', 'total_price': '1,990'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '35.11', 'square_price': '45.51', 'total_price': '1,598'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.84', 'square_price': '50.30', 'total_price': '1,350'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '30.93', 'square_price': '64.66', 'total_price': '2,000'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '34.17', 'square_price': '49.17', 'total_price': '1,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '34.89', 'square_price': '74.18', 'total_price': '2,588'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '24.12', 'square_price': '87.06', 'total_price': '2,100'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.84', 'square_price': '56.52', 'total_price': '1,630'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '36.25', 'square_price': '66.15', 'total_price': '2,398'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.47', 'square_price': '83.73', 'total_price': '2,300'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.31', 'square_price': '75.83', 'total_price': '2,450'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '37.73', 'square_price': '52.48', 'total_price': '1,980'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '52.02', 'square_price': '49.98', 'total_price': '2,600'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '31.64', 'square_price': '43.62', 'total_price': '1,380'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '34.9', 'square_price': '33.81', 'total_price': '1,180'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.69', 'square_price': '45.27', 'total_price': '1,480'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.5', 'square_price': '69.23', 'total_price': '2,250'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '25.97', 'square_price': '49.29', 'total_price': '1,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.05', 'square_price': '74.26', 'total_price': '2,380'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '46.12', 'square_price': '73.29', 'total_price': '3,380'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '39.29', 'square_price': '63.12', 'total_price': '2,480'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '62.78', 'square_price': '47.75', 'total_price': '2,998'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '30.49', 'square_price': '72.15', 'total_price': '2,200'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.54', 'square_price': '153.29', 'total_price': '4,988'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '19.77', 'square_price': '80.93', 'total_price': '1,600'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.32', 'square_price': '49.80', 'total_price': '1,460'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '35.51', 'square_price': '52.32', 'total_price': '1,858'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '33.38', 'square_price': '53.92', 'total_price': '1,800'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.13', 'square_price': '75.77', 'total_price': '1,980'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '33.72', 'square_price': '85.65', 'total_price': '2,888'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '51.35', 'square_price': '58.19', 'total_price': '2,988'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.25', 'square_price': '37.54', 'total_price': '1,098'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '40.88', 'square_price': '45.99', 'total_price': '1,880'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.04', 'square_price': '45.65', 'total_price': '1,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '24.98', 'square_price': '62.45', 'total_price': '1,560'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.96', 'square_price': '67.24', 'total_price': '1,880'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '37.34', 'square_price': '61.06', 'total_price': '2,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.1', 'square_price': '52.34', 'total_price': '1,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '64.75', 'square_price': '69.47', 'total_price': '4,498'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '8.82', 'square_price': '65.76', 'total_price': '580'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.97', 'square_price': '57.99', 'total_price': '1,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '44.72', 'square_price': '42.04', 'total_price': '1,880'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '30.93', 'square_price': '48.11', 'total_price': '1,488'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '37.82', 'square_price': '64.78', 'total_price': '2,450'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '43.15', 'square_price': '50.98', 'total_price': '2,200'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '33.81', 'square_price': '46.97', 'total_price': '1,588'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '45.92', 'square_price': '34.80', 'total_price': '1,598'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '33.55', 'square_price': '50.07', 'total_price': '1,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.54', 'square_price': '50.47', 'total_price': '1,390'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32', 'square_price': '73.38', 'total_price': '2,348'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '49.39', 'square_price': '78.56', 'total_price': '3,880'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '35.61', 'square_price': '55.60', 'total_price': '1,980'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '49.9', 'square_price': '55.87', 'total_price': '2,788'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '25.87', 'square_price': '88.13', 'total_price': '2,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.4', 'square_price': '78.64', 'total_price': '2,076'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '30.64', 'square_price': '57.11', 'total_price': '1,750'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '30.56', 'square_price': '47.45', 'total_price': '1,450'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '55.81', 'square_price': '51.60', 'total_price': '2,880'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '22.23', 'square_price': '79.17', 'total_price': '1,760'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.23', 'square_price': '79.32', 'total_price': '2,160'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.94', 'square_price': '106.25', 'total_price': '3,500'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.36', 'square_price': '58.10', 'total_price': '1,880'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '23.94', 'square_price': '79.28', 'total_price': '1,898'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '43.12', 'square_price': '55.43', 'total_price': '2,390'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '25.57', 'square_price': '89.17', 'total_price': '2,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.15', 'square_price': '50.28', 'total_price': '1,365'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '42.51', 'square_price': '37.17', 'total_price': '1,580'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '25.29', 'square_price': '58.52', 'total_price': '1,480'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.85', 'square_price': '58.23', 'total_price': '1,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '39.22', 'square_price': '63.23', 'total_price': '2,480'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '43.68', 'square_price': '63.64', 'total_price': '2,780'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '31.91', 'square_price': '52.65', 'total_price': '1,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '42.33', 'square_price': '51.69', 'total_price': '2,188'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '19.8', 'square_price': '60.61', 'total_price': '1,200'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '31.43', 'square_price': '99.84', 'total_price': '3,138'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '22.3', 'square_price': '60.54', 'total_price': '1,350'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.01', 'square_price': '51.77', 'total_price': '1,450'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '31.42', 'square_price': '50.54', 'total_price': '1,588'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '38.34', 'square_price': '48.20', 'total_price': '1,848'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '31.42', 'square_price': '50.54', 'total_price': '1,588'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.91', 'square_price': '54.69', 'total_price': '1,800'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '35.43', 'square_price': '50.24', 'total_price': '1,780'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '30.46', 'square_price': '58.44', 'total_price': '1,780'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '34.51', 'square_price': '52.97', 'total_price': '1,828'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '42.22', 'square_price': '46.42', 'total_price': '1,960'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.69', 'square_price': '63.75', 'total_price': '2,084'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.37', 'square_price': '40.12', 'total_price': '1,058'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '31.11', 'square_price': '89.36', 'total_price': '2,780'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '41.86', 'square_price': '54.90', 'total_price': '2,298'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.77', 'square_price': '109.49', 'total_price': '3,150'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '31.03', 'square_price': '80.18', 'total_price': '2,488'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '31.69', 'square_price': '62.48', 'total_price': '1,980'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.39', 'square_price': '57.16', 'total_price': '1,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '77.71', 'square_price': '30.24', 'total_price': '2,350'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '33.26', 'square_price': '54.06', 'total_price': '1,798'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '19.92', 'square_price': '72.79', 'total_price': '1,450'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '81.29', 'square_price': '35.06', 'total_price': '2,850'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.77', 'square_price': '79.34', 'total_price': '2,600'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '25.97', 'square_price': '50.06', 'total_price': '1,300'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '59.33', 'square_price': '62.16', 'total_price': '3,688'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '22.84', 'square_price': '76.09', 'total_price': '1,738'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '30.2', 'square_price': '171.79', 'total_price': '5,188'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.71', 'square_price': '127.90', 'total_price': '3,800'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '24.8', 'square_price': '72.58', 'total_price': '1,800'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.28', 'square_price': '52.89', 'total_price': '1,390'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.35', 'square_price': '408.86', 'total_price': '12,000'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '23.02', 'square_price': '58.99', 'total_price': '1,358'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '43.12', 'square_price': '55.43', 'total_price': '2,390'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.53', 'square_price': '130.04', 'total_price': '3,580'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.56', 'square_price': '46.44', 'total_price': '1,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '19.8', 'square_price': '64.65', 'total_price': '1,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '39.55', 'square_price': '60.18', 'total_price': '2,380'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.35', 'square_price': '408.86', 'total_price': '12,000'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.2', 'square_price': '54.71', 'total_price': '1,488'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.56', 'square_price': '46.44', 'total_price': '1,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '31.95', 'square_price': '83.88', 'total_price': '2,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '25.75', 'square_price': '264.08', 'total_price': '6,800'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.31', 'square_price': '64.82', 'total_price': '1,900'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.69', 'square_price': '52.00', 'total_price': '1,388'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '43.15', 'square_price': '57.20', 'total_price': '2,468'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.11', 'square_price': '56.68', 'total_price': '1,480'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '24.12', 'square_price': '194.03', 'total_price': '4,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '36.54', 'square_price': '73.34', 'total_price': '2,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.97', 'square_price': '64.89', 'total_price': '1,750'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '24.05', 'square_price': '87.32', 'total_price': '2,100'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '32.28', 'square_price': '92.94', 'total_price': '3,000'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '41.15', 'square_price': '63.18', 'total_price': '2,600'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '25.68', 'square_price': '84.89', 'total_price': '2,180'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '42.87', 'square_price': '76.70', 'total_price': '3,288'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.69', 'square_price': '59.95', 'total_price': '1,780'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '29.71', 'square_price': '56.55', 'total_price': '1,680'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '38.97', 'square_price': '102.13', 'total_price': '3,980'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '59.32', 'square_price': '75.02', 'total_price': '4,450'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '27.63', 'square_price': '89.76', 'total_price': '2,480'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '34.55', 'square_price': '65.99', 'total_price': '2,280'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '22.85', 'square_price': '47.61', 'total_price': '1,088'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.94', 'square_price': '151.74', 'total_price': '4,088'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '21.64', 'square_price': '60.07', 'total_price': '1,300'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '40.21', 'square_price': '59.59', 'total_price': '2,396'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '28.35', 'square_price': '64.90', 'total_price': '1,840'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '34.42', 'square_price': '52.27', 'total_price': '1,799'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '22.85', 'square_price': '70.02', 'total_price': '1,600'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '26.54', 'square_price': '59.08', 'total_price': '1,568'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '19.47', 'square_price': '138.06', 'total_price': '2,688'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '24.71', 'square_price': '59.89', 'total_price': '1,480'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '40.88', 'square_price': '45.99', 'total_price': '1,880'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '35.4', 'square_price': '120.06', 'total_price': '4,250'}
# {'district': 'Wenshan', 'type': 'apartment', 'square': '60.63', 'square_price': '54.99', 'total_price': '3,334'}
# Total items: 202

# %%
import json

# Your code for extracting data and populating result_list

# Define the output JSON file path
output_file = 'output_buy_wenshan_apt.json'

# Write the result_list to the JSON file with proper encoding
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(result_list, f, ensure_ascii=False)

print("Data exported to", output_file)
# Out:
# Data exported to output_buy_wenshan_apt.json
